# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization, Conv1D, MaxPool1D
from tensorflow.keras.optimizers import Adam

# %%
import pandas as pd
import numpy as np
#import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv(r'E:\Machine Learning datasets\Credit card fraud detection\creditcard.csv')
data.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.656562e-16 -3.444850e-16  2.578648e-16  4.471968e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.687098e-15 -3.666453e-16 -1.220404e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
not_fraud = data[data['Class']==0]
fraud = data[data['Class']==1]

# %%
not_fraud = not_fraud.sample(fraud.shape[0])
not_fraud.shape
# Out:
# (492, 31)

# %%
data = fraud.append(not_fraud, ignore_index=True)
data
# Out:
#          Time         V1        V2        V3        V4        V5        V6  \
# 0       406.0  -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 1       472.0  -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 2      4462.0  -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 3      6986.0  -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 4      7519.0   1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ..        ...        ...       ...       ...       ...       ...       ...
# 979  134208.0 -11.265784 -4.311819 -4.135526 -0.156040  1.863257  0.297035
# 980   46079.0   1.167643 -0.336057  0.649466  0.092566 -0.913074 -0.502738
# 981  125621.0  -1.801523  1.755805 -0.747802  1.170237  3.501295  1.475223
# 982    9150.0  -1.951246  0.019177  1.382606  3.348795 -1.767142  3.173775
# 983  121683.0   1.858892 -0.646340 -0.526038  0.172724 -0.585609 -0.101488
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 0   -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 1    0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 2    0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 3   -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 4    1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
# ..        ...       ...       ...  ...       ...       ...       ...
# 979  0.696259 -0.061234  2.783926  ... -2.152203  0.083788  0.497759
# 980 -0.496951  0.152469  0.757696  ... -0.179756 -0.676341  0.192565
# 981 -4.232705 -4.573079 -1.083266  ... -2.464719  0.915459 -3.751380
# 982  0.755819 -3.092119  0.115093  ... -1.345743  0.520662 -2.381293
# 983 -0.599623  0.176607  0.918732  ... -0.193361 -0.713978  0.434043
#
#           V24       V25       V26       V27       V28  Amount  Class
# 0    0.320198  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 1   -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00      1
# 2   -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93      1
# 3   -0.053502  0.252405 -0.657488 -0.827136  0.849573   59.00      1
# 4   -1.632653  1.488901  0.566797 -0.010016  0.146793    1.00      1
# ..        ...       ...       ...       ...       ...     ...    ...
# 979 -0.795596  0.872245 -0.222272 -1.840666  1.620507   85.65      0
# 980  0.051593 -0.157112  0.823604 -0.067120  0.010579   30.80      0
# 981 -0.887290 -0.434907  1.281870  0.481453  0.335289   12.31      0
# 982 -0.602808 -0.489148  0.336239  0.444819 -0.242005  919.17      0
# 983  0.722452 -0.723378  0.174451 -0.066322 -0.038841   64.99      0
#
# [984 rows x 31 columns]

# %%
X = data.drop('Class', axis=1)
y = data['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
epochs = 20
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=2, activation='relu', input_shape=X_train[0].shape))
model.add(BatchNormalization())
model.add(Dropout(0.2))
          
model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
          
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 29, 32)            96
# _________________________________________________________________
# batch_normalization (BatchNo (None, 29, 32)            128
# _________________________________________________________________
# dropout (Dropout)            (None, 29, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 28, 64)            4160
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 64)            256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1792)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                114752
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 119,457
# Trainable params: 119,265
# Non-trainable params: 192
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.00005), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), verbose=1)
# Out:
# Train on 787 samples, validate on 197 samples
# Epoch 1/20
# 787/787 [==============================] - 5s 6ms/sample - loss: 0.7232 - accuracy: 0.6417 - val_loss: 0.6395 - val_accuracy: 0.8173
# Epoch 2/20
# 787/787 [==============================] - 0s 553us/sample - loss: 0.5859 - accuracy: 0.7484 - val_loss: 0.6031 - val_accuracy: 0.8071
# Epoch 3/20
# 787/787 [==============================] - 0s 478us/sample - loss: 0.4589 - accuracy: 0.8030 - val_loss: 0.5711 - val_accuracy: 0.8122
# Epoch 4/20
# 787/787 [==============================] - 0s 402us/sample - loss: 0.4480 - accuracy: 0.8221 - val_loss: 0.5379 - val_accuracy: 0.8325
# Epoch 5/20
# 787/787 [==============================] - 0s 383us/sample - loss: 0.4089 - accuracy: 0.8488 - val_loss: 0.5068 - val_accuracy: 0.8832
# Epoch 6/20
# 787/787 [==============================] - 0s 380us/sample - loss: 0.3682 - accuracy: 0.8399 - val_loss: 0.4705 - val_accuracy: 0.9036
# Epoch 7/20
# 787/787 [==============================] - 0s 381us/sample - loss: 0.3438 - accuracy: 0.8793 - val_loss: 0.4368 - val_accuracy: 0.9036
# Epoch 8/20
# 787/787 [==============================] - 0s 390us/sample - loss: 0.3425 - accuracy: 0.8806 - val_loss: 0.4049 - val_accuracy: 0.9086
# Epoch 9/20
# 787/787 [==============================] - 0s 350us/sample - loss: 0.3238 - accuracy: 0.8895 - val_loss: 0.3786 - val_accuracy: 0.9137
# Epoch 10/20
# 787/787 [==============================] - 0s 364us/sample - loss: 0.3132 - accuracy: 0.8717 - val_loss: 0.3504 - val_accuracy: 0.9137
# Epoch 11/20
# 787/787 [==============================] - 0s 336us/sample - loss: 0.3100 - accuracy: 0.8831 - val_loss: 0.3244 - val_accuracy: 0.9188
# Epoch 12/20
# 787/787 [==============================] - 0s 362us/sample - loss: 0.2950 - accuracy: 0.8958 - val_loss: 0.3034 - val_accuracy: 0.9188
# Epoch 13/20
# 787/787 [==============================] - 0s 336us/sample - loss: 0.2764 - accuracy: 0.9047 - val_loss: 0.2845 - val_accuracy: 0.9188
# Epoch 14/20
# 787/787 [==============================] - 0s 355us/sample - loss: 0.2961 - accuracy: 0.9009 - val_loss: 0.2657 - val_accuracy: 0.9188
# Epoch 15/20
# 787/787 [==============================] - 0s 359us/sample - loss: 0.2716 - accuracy: 0.9085 - val_loss: 0.2520 - val_accuracy: 0.9188
# Epoch 16/20
# 787/787 [==============================] - 0s 364us/sample - loss: 0.2514 - accuracy: 0.9098 - val_loss: 0.2420 - val_accuracy: 0.9188
# Epoch 17/20
# 787/787 [==============================] - 0s 356us/sample - loss: 0.2575 - accuracy: 0.9098 - val_loss: 0.2321 - val_accuracy: 0.9188
# Epoch 18/20
# 787/787 [==============================] - 0s 372us/sample - loss: 0.2377 - accuracy: 0.9187 - val_loss: 0.2243 - val_accuracy: 0.9188
# Epoch 19/20
# 787/787 [==============================] - 0s 368us/sample - loss: 0.2479 - accuracy: 0.9072 - val_loss: 0.2195 - val_accuracy: 0.9188
# Epoch 20/20
# 787/787 [==============================] - 0s 372us/sample - loss: 0.2461 - accuracy: 0.9199 - val_loss: 0.2137 - val_accuracy: 0.9188

# %%
history.history
# Out:
# {'loss': [0.7231644950949101,
#   0.585937091780133,
#   0.4588963105006018,
#   0.44798596485445735,
#   0.40885262053076465,
#   0.36820178051991564,
#   0.3437652962786421,
#   0.3424889617226781,
#   0.32382539263068494,
#   0.31319125218191474,
#   0.3099566838186911,
#   0.29501070966411574,
#   0.27644690626988416,
#   0.29609030204928055,
#   0.2715973623257883,
#   0.2513610332863455,
#   0.2574767516369741,
#   0.23773556421339284,
#   0.2479170897864326,
#   0.24605162273216732],
#  'accuracy': [0.64167726,
#   0.7484117,
#   0.80304956,
#   0.8221093,
#   0.8487929,
#   0.83989835,
#   0.87928843,
#   0.8805591,
#   0.88945365,
#   0.8716645,
#   0.8831004,
#   0.89580685,
#   0.9047014,
#   0.90088946,
#   0.90851337,
#   0.909784,
#   0.909784,
#   0.9186785,
#   0.9072427,
#   0.9199492],
#  'val_loss': [0.6394720144078211,
#   0.6031225632289945,
#   0.5711364485890732,
#   0.537947516150886,
#   0.5067577262215203,
#   0.47050688744801555,
#   0.4368301179203285,
#   0.4049267983678634,
#   0.3786045781852025,
#   0.3503917351289449,
#   0.3244419448871903,
#   0.3033822646298384,
#   0.28451448421792935,
#   0.26568934767681934,
#   0.2520454830778432,
#   0.24201187461160767,
#   0.23205055130012145,
#   0.22429730160738612,
#   0.21946248737386034,
#   0.21368149217917834],
#  'val_accuracy': [0.8172589,
#   0.8071066,
#   0.8121827,
#   0.8324873,
#   0.88324875,
#   0.9035533,
#   0.9035533,
#   0.9086294,
#   0.9137056,
#   0.9137056,
#   0.9187817,
#   0.9187817,
#   0.9187817,
#   0.9187817,
#   0.9187817,
#   0.9187817,
#   0.9187817,
#   0.9187817,
#   0.9187817,
#   0.9187817]}

# %%
def plot_learning_curve(history, epoch):
    
    epoch_range = range(1, epoch+1)
    
    #plotting training and validation accuracy
    plt.plot(epoch_range,history.history['accuracy'])
    plt.plot(epoch_range,history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train','Val'], loc='upper_left')
    plt.show()

    #plotting training and validation loss
    plt.plot(epoch_range,history.history['loss'])
    plt.plot(epoch_range,history.history['val_loss'])
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train','Val'], loc='upper_left')
    plt.show()

# %%
plot_learning_curve(history, epochs)

# %%
epochs = 50
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=2, activation='relu', input_shape=X_train[0].shape))
model.add(BatchNormalization())
model.add(MaxPool1D(2))
model.add(Dropout(0.2))
          
model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool1D(2))
model.add(Dropout(0.5))
          
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), verbose=1)
plot_learning_curve(history, epochs)
# Out:
# Train on 787 samples, validate on 197 samples
# Epoch 1/50
# 787/787 [==============================] - 3s 4ms/sample - loss: 1.1746 - accuracy: 0.5070 - val_loss: 0.6629 - val_accuracy: 0.5939
# Epoch 2/50
# 787/787 [==============================] - 0s 316us/sample - loss: 0.8285 - accuracy: 0.6391 - val_loss: 0.6318 - val_accuracy: 0.7716
# Epoch 3/50
# 787/787 [==============================] - 0s 322us/sample - loss: 0.7888 - accuracy: 0.6607 - val_loss: 0.6018 - val_accuracy: 0.7716
# Epoch 4/50
# 787/787 [==============================] - 0s 311us/sample - loss: 0.6254 - accuracy: 0.7357 - val_loss: 0.5714 - val_accuracy: 0.7665
# Epoch 5/50
# 787/787 [==============================] - 0s 328us/sample - loss: 0.5928 - accuracy: 0.7586 - val_loss: 0.5377 - val_accuracy: 0.7665
# Epoch 6/50
# 787/787 [==============================] - 0s 314us/sample - loss: 0.5206 - accuracy: 0.7929 - val_loss: 0.5052 - val_accuracy: 0.7665
# Epoch 7/50
# 787/787 [==============================] - 0s 334us/sample - loss: 0.5319 - accuracy: 0.7916 - val_loss: 0.4755 - val_accuracy: 0.7665
# Epoch 8/50
# 787/787 [==============================] - 0s 317us/sample - loss: 0.4593 - accuracy: 0.8132 - val_loss: 0.4479 - val_accuracy: 0.7868
# Epoch 9/50
# 787/787 [==============================] - 0s 318us/sample - loss: 0.4234 - accuracy: 0.8259 - val_loss: 0.4220 - val_accuracy: 0.8020
# Epoch 10/50
# 787/787 [==============================] - 0s 335us/sample - loss: 0.4002 - accuracy: 0.8335 - val_loss: 0.3982 - val_accuracy: 0.8274
# Epoch 11/50
# 787/787 [==============================] - 0s 304us/sample - loss: 0.3617 - accuracy: 0.8628 - val_loss: 0.3763 - val_accuracy: 0.8376
# Epoch 12/50
# 787/787 [==============================] - 0s 315us/sample - loss: 0.3788 - accuracy: 0.8590 - val_loss: 0.3561 - val_accuracy: 0.8528
# Epoch 13/50
# 787/787 [==============================] - 0s 311us/sample - loss: 0.3579 - accuracy: 0.8742 - val_loss: 0.3388 - val_accuracy: 0.8579
# Epoch 14/50
# 787/787 [==============================] - 0s 315us/sample - loss: 0.3858 - accuracy: 0.8475 - val_loss: 0.3257 - val_accuracy: 0.8629
# Epoch 15/50
# 787/787 [==============================] - 0s 305us/sample - loss: 0.3277 - accuracy: 0.8818 - val_loss: 0.3145 - val_accuracy: 0.8680
# Epoch 16/50
# 787/787 [==============================] - 0s 326us/sample - loss: 0.3511 - accuracy: 0.8717 - val_loss: 0.3051 - val_accuracy: 0.8731
# Epoch 17/50
# 787/787 [==============================] - 0s 301us/sample - loss: 0.3438 - accuracy: 0.8742 - val_loss: 0.2976 - val_accuracy: 0.8782
# Epoch 18/50
# 787/787 [==============================] - 0s 332us/sample - loss: 0.3671 - accuracy: 0.8628 - val_loss: 0.2897 - val_accuracy: 0.8832
# Epoch 19/50
# 787/787 [==============================] - 0s 412us/sample - loss: 0.3153 - accuracy: 0.8882 - val_loss: 0.2849 - val_accuracy: 0.8832
# Epoch 20/50
# 787/787 [==============================] - 0s 384us/sample - loss: 0.3179 - accuracy: 0.8844 - val_loss: 0.2809 - val_accuracy: 0.8832
# Epoch 21/50
# 787/787 [==============================] - 0s 365us/sample - loss: 0.3603 - accuracy: 0.8780 - val_loss: 0.2790 - val_accuracy: 0.8832
# Epoch 22/50
# 787/787 [==============================] - 0s 375us/sample - loss: 0.3388 - accuracy: 0.8793 - val_loss: 0.2760 - val_accuracy: 0.8832
# Epoch 23/50
# 787/787 [==============================] - 0s 365us/sample - loss: 0.2791 - accuracy: 0.8920 - val_loss: 0.2750 - val_accuracy: 0.8883
# Epoch 24/50
# 787/787 [==============================] - 0s 388us/sample - loss: 0.3000 - accuracy: 0.8933 - val_loss: 0.2768 - val_accuracy: 0.8832
# Epoch 25/50
# 787/787 [==============================] - 0s 361us/sample - loss: 0.2681 - accuracy: 0.8831 - val_loss: 0.2772 - val_accuracy: 0.8883
# Epoch 26/50
# 787/787 [==============================] - 0s 375us/sample - loss: 0.3126 - accuracy: 0.8882 - val_loss: 0.2775 - val_accuracy: 0.8883
# Epoch 27/50
# 787/787 [==============================] - 0s 372us/sample - loss: 0.2724 - accuracy: 0.9022 - val_loss: 0.2762 - val_accuracy: 0.8934
# Epoch 28/50
# 787/787 [==============================] - 0s 385us/sample - loss: 0.2715 - accuracy: 0.8983 - val_loss: 0.2745 - val_accuracy: 0.9086
# Epoch 29/50
# 787/787 [==============================] - 0s 373us/sample - loss: 0.3288 - accuracy: 0.8882 - val_loss: 0.2724 - val_accuracy: 0.9036
# Epoch 30/50
# 787/787 [==============================] - 0s 384us/sample - loss: 0.2809 - accuracy: 0.8945 - val_loss: 0.2708 - val_accuracy: 0.9086
# Epoch 31/50
# 787/787 [==============================] - 0s 385us/sample - loss: 0.2709 - accuracy: 0.8996 - val_loss: 0.2694 - val_accuracy: 0.9086
# Epoch 32/50
# 787/787 [==============================] - 0s 366us/sample - loss: 0.2811 - accuracy: 0.8933 - val_loss: 0.2721 - val_accuracy: 0.9036
# Epoch 33/50
# 787/787 [==============================] - 0s 361us/sample - loss: 0.2580 - accuracy: 0.9098 - val_loss: 0.2697 - val_accuracy: 0.9086
# Epoch 34/50
# 787/787 [==============================] - 0s 383us/sample - loss: 0.2920 - accuracy: 0.9085 - val_loss: 0.2691 - val_accuracy: 0.9086
# Epoch 35/50
# 787/787 [==============================] - 0s 377us/sample - loss: 0.2733 - accuracy: 0.9022 - val_loss: 0.2691 - val_accuracy: 0.9086
# Epoch 36/50
# 787/787 [==============================] - 0s 377us/sample - loss: 0.2723 - accuracy: 0.8945 - val_loss: 0.2699 - val_accuracy: 0.9036
# Epoch 37/50
# 787/787 [==============================] - 0s 371us/sample - loss: 0.2460 - accuracy: 0.9123 - val_loss: 0.2684 - val_accuracy: 0.9086
# Epoch 38/50
# 787/787 [==============================] - 0s 353us/sample - loss: 0.2712 - accuracy: 0.9034 - val_loss: 0.2679 - val_accuracy: 0.9137
# Epoch 39/50
# 787/787 [==============================] - 0s 361us/sample - loss: 0.2772 - accuracy: 0.9034 - val_loss: 0.2670 - val_accuracy: 0.9137
# Epoch 40/50
# 787/787 [==============================] - 0s 348us/sample - loss: 0.2320 - accuracy: 0.9199 - val_loss: 0.2662 - val_accuracy: 0.9137
# Epoch 41/50
# 787/787 [==============================] - 0s 345us/sample - loss: 0.2581 - accuracy: 0.9047 - val_loss: 0.2661 - val_accuracy: 0.9137
# Epoch 42/50
# 787/787 [==============================] - 0s 337us/sample - loss: 0.2601 - accuracy: 0.9060 - val_loss: 0.2626 - val_accuracy: 0.9137
# Epoch 43/50
# 787/787 [==============================] - 0s 351us/sample - loss: 0.2607 - accuracy: 0.9123 - val_loss: 0.2626 - val_accuracy: 0.9137
# Epoch 44/50
# 787/787 [==============================] - 0s 369us/sample - loss: 0.2273 - accuracy: 0.9187 - val_loss: 0.2644 - val_accuracy: 0.9137
# Epoch 45/50
# 787/787 [==============================] - 0s 352us/sample - loss: 0.2618 - accuracy: 0.9047 - val_loss: 0.2649 - val_accuracy: 0.9137
# Epoch 46/50
# 787/787 [==============================] - 0s 353us/sample - loss: 0.2353 - accuracy: 0.9199 - val_loss: 0.2630 - val_accuracy: 0.9137
# Epoch 47/50
# 787/787 [==============================] - 0s 400us/sample - loss: 0.2401 - accuracy: 0.9136 - val_loss: 0.2624 - val_accuracy: 0.9137
# Epoch 48/50
# 787/787 [==============================] - 0s 327us/sample - loss: 0.2396 - accuracy: 0.9136 - val_loss: 0.2603 - val_accuracy: 0.9137
# Epoch 49/50
# 787/787 [==============================] - 0s 305us/sample - loss: 0.2341 - accuracy: 0.9161 - val_loss: 0.2618 - val_accuracy: 0.9086
# Epoch 50/50
# 787/787 [==============================] - 0s 302us/sample - loss: 0.2174 - accuracy: 0.9111 - val_loss: 0.2631 - val_accuracy: 0.9086
